# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Tara

# %% [markdown]
# ###### I am interested in data science because of the potential it offers to address international development  challenges. By yielding insights into data, data science tools can help policymakers to make better decisions - and subsequently evaluate the impact of those decisions - in fields as diverse as governance, public health, education, food security, and environmental issues.

# %% [markdown]
# ### My code raises a given number to the power of 2

# %%
import numpy as np

# %%
a = 2

# %%
pow(a,2)
# Out:
# 4

# %% [markdown]
#  - Thanks for reading
#  - Great resource on Jupyter markdown: [https://ingeh.medium.com/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed](http://url)
#  - Creating a bulleted list
#  - Creating a horizontal line:
#  ***
